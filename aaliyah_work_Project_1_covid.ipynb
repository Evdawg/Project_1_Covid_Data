# %% [markdown]
# ## Evan Work Area

# %%
# import dependencies and setup
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pprint import pprint
from pathlib import Path

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Load csv file(s)
all_states_sheet = Path("Resources/EARN_all_states.csv")


# Read csv file(s) as a DataFrame
all_states_df = pd.read_csv(all_states_sheet, skipinitialspace= True, low_memory=False)


# preview the raw DataFrame
print(len(all_states_df['Project ID']))
all_states_df.head()


all_states_df.columns = all_states_df.columns.str.strip()

print(all_states_df.columns)
# Out:
# 35710
# Index(['Project ID', 'Recipient-ID', 'Recipient Name', 'State/Territory',
#        'StateList', 'Reporting Tier', 'Recipient Type', 'Completion Status',
#        'Project Name', 'Expenditure Category Group', 'Expenditure Category',
#        'Project Description', 'Adopted Budget', 'Total Cumulative Obligations',
#        'Total Cumulative Expenditures',
#        'Community benefit agreement? (Infrastructure Only)',
#        'Complying with David Bacon? (Infrastructure Only)',
#        'Project labor agreement? (Infrastructure Only)',
#        'Primary Demographic Served (Select Expenditure Categories Only)'],
#       dtype='object')

# %%
# Review list of NA values in the 'Project Description' column
nan_values = all_states_df[all_states_df['Project Description'].isna()]

# print(len(nan_values))
print(f'There are {len(nan_values)} columns with NA values in "Project Description" column:')

#nan_values
# Out:
# There are 4 columns with NA values in "Project Description" column:

# %%
# Drop these rows where the column has NaN value
    # source: https://towardsdatascience.com/how-to-drop-rows-in-pandas-dataframes-with-nan-values-in-certain-columns-7613ad1a7f25
    
all_states_df = all_states_df.dropna(subset=['Project Description'], how='all')

# confirm 4 rows were dropped by reviewing column length count:

print(f'The DataFrame now has {len(all_states_df["Project ID"])} rows of data.')
all_states_df.head(1)
# Out:
# The DataFrame now has 35706 rows of data.
#    Project ID Recipient-ID         Recipient Name State/Territory StateList  \
# 0  TPN-039343   RCP-039196  Woodbury County, Iowa            Iowa      Iowa
#
#                                       Reporting Tier    Recipient Type  \
# 0  Tier 2.  Metropolitan cities and counties with...  Local Government
#
#   Completion Status      Project Name Expenditure Category Group  \
# 0         Cancelled  LEC Main project            1-Public Health
#
#                                 Expenditure Category     Project Description  \
# 0  1.4-Prevention in Congregate Settings (Nursing...  HVAC to mitigate covid
#
#   Adopted Budget Total Cumulative Obligations Total Cumulative Expenditures  \
# 0           -                            -                             -
#
#   Community benefit agreement? (Infrastructure Only)  \
# 0                                                NaN
#
#   Complying with David Bacon? (Infrastructure Only)  \
# 0                                               NaN
#
#   Project labor agreement? (Infrastructure Only)  \
# 0                                            NaN
#
#   Primary Demographic Served (Select Expenditure Categories Only)
# 0                               1 Imp General Public

# %%
# Make the Project Description values all lowercase for value search:
all_states_df['Project Description'] = all_states_df['Project Description'].str.lower()

print(f'The Project Description column has been set to lowercase for all string values:')
all_states_df.head(2)
# Out:
# The Project Description column has been set to lowercase for all string values:
#    Project ID Recipient-ID                            Recipient Name  \
# 0  TPN-039343   RCP-039196                     Woodbury County, Iowa
# 1  TPN-039461   RCP-036070  Lexington-Fayette Urban County, Kentucky
#
#   State/Territory StateList  \
# 0            Iowa      Iowa
# 1        Kentucky  Kentucky
#
#                                       Reporting Tier    Recipient Type  \
# 0  Tier 2.  Metropolitan cities and counties with...  Local Government
# 1  Tier 1. States, U.S. territories, metropolitan...  Local Government
#
#   Completion Status                            Project Name  \
# 0         Cancelled                        LEC Main project
# 1         Cancelled  Housing Stabilization - Salvation Army
#
#   Expenditure Category Group  \
# 0            1-Public Health
# 1      6-Revenue Replacement
#
#                                 Expenditure Category  \
# 0  1.4-Prevention in Congregate Settings (Nursing...
# 1               6.1-Provision of Government Services
#
#                                  Project Description Adopted Budget  \
# 0                             hvac to mitigate covid           -
# 1  financial assistance to salvation army to impr...           -
#
#   Total Cumulative Obligations Total Cumulative Expenditures  \
# 0                         -                             -
# 1                         -                             -
#
#   Community benefit agreement? (Infrastructure Only)  \
# 0                                                NaN
# 1                                                NaN
#
#   Complying with David Bacon? (Infrastructure Only)  \
# 0                                               NaN
# 1                                               NaN
#
#   Project labor agreement? (Infrastructure Only)  \
# 0                                            NaN
# 1                                            NaN
#
#   Primary Demographic Served (Select Expenditure Categories Only)
# 0                               1 Imp General Public
# 1                                                NaN

# %%
# Brainstorm a list of words to filter the 'Project Description' column by.
    ## this list will be used to filter that column so that we are only working with projects that
    ## are actually covid related.
    
# TODO: confirm string case does not affect search results. eg) lowercase moderna vs Moderna.
search_term_list = ['covid', 'covid-19', 'vaccine', 'vaccination', 'vaccinated', 'moderna', 'pfizer', 'johnson & johnson', 'janssen']

# %%
# Filter the dataframe column 'Project Description'
    ## source: https://stackoverflow.com/questions/28679930/how-to-drop-rows-from-pandas-data-frame-that-contains-a-particular-string-in-a-p

    
covid_projects_df = all_states_df[all_states_df['Project Description'].str.contains('|'.join(search_term_list))]


# print(len(all_states_df['Project Description']))
print(f'The number of rows containing covid/vaccine search criteria terms is {len(covid_projects_df["Project ID"])}')
covid_projects_df.head(4)
# Out:
# The number of rows containing covid/vaccine search criteria terms is 8225
#     Project ID Recipient-ID                            Recipient Name  \
# 0   TPN-039343   RCP-039196                     Woodbury County, Iowa
# 1   TPN-039461   RCP-036070  Lexington-Fayette Urban County, Kentucky
# 5   TPN-055785   RCP-035970                            State Of Idaho
# 10  TPN-056253   RCP-035970                            State Of Idaho
#
#    State/Territory StateList  \
# 0             Iowa      Iowa
# 1         Kentucky  Kentucky
# 5            Idaho     Idaho
# 10           Idaho     Idaho
#
#                                        Reporting Tier    Recipient Type  \
# 0   Tier 2.  Metropolitan cities and counties with...  Local Government
# 1   Tier 1. States, U.S. territories, metropolitan...  Local Government
# 5   Tier 1. States, U.S. territories, metropolitan...          State/DC
# 10  Tier 1. States, U.S. territories, metropolitan...          State/DC
#
#    Completion Status                            Project Name  \
# 0          Cancelled                        LEC Main project
# 1          Cancelled  Housing Stabilization - Salvation Army
# 5          Cancelled              Reserve for Covid 19 costs
# 10         Cancelled                       DHW Home visiting
#
#      Expenditure Category Group  \
# 0               1-Public Health
# 1         6-Revenue Replacement
# 5               1-Public Health
# 10  2-Negative Economic Impacts
#
#                                  Expenditure Category  \
# 0   1.4-Prevention in Congregate Settings (Nursing...
# 1                6.1-Provision of Government Services
# 5                   1.14-Other Public Health Services
# 10  2.12-Healthy Childhood Environments: Home Visi...
#
#                                   Project Description Adopted Budget  \
# 0                              hvac to mitigate covid           -
# 1   financial assistance to salvation army to impr...           -
# 5        additional unanticipated covid medical costs           -
# 10  •\tthe idaho department of health and welfare ...           -
#
#    Total Cumulative Obligations Total Cumulative Expenditures  \
# 0                          -                             -
# 1                          -                             -
# 5                          -                             -
# 10                         -                             -
#
#    Community benefit agreement? (Infrastructure Only)  \
# 0                                                 NaN
# 1                                                 NaN
# 5                                                 NaN
# 10                                                NaN
#
#    Complying with David Bacon? (Infrastructure Only)  \
# 0                                                NaN
# 1                                                NaN
# 5                                                NaN
# 10                                               NaN
#
#    Project labor agreement? (Infrastructure Only)  \
# 0                                             NaN
# 1                                             NaN
# 5                                             NaN
# 10                                            NaN
#
#    Primary Demographic Served (Select Expenditure Categories Only)
# 0                                1 Imp General Public
# 1                                                 NaN
# 5                                1 Imp General Public
# 10          14 Dis Imp Low income HHs and populations

# %%
# Now format all budget related columns as integers for summing in the .groupby step:
# note that pandas imported the csv columns as an object type and not strings/ints, etc:

# print(all_states_df.dtypes)
print(f'\n----------------------------\n')
print(covid_projects_df.dtypes)
# Out:
# ----------------------------
#
# Project ID                                                         object
# Recipient-ID                                                       object
# Recipient Name                                                     object
# State/Territory                                                    object
# StateList                                                          object
# Reporting Tier                                                     object
# Recipient Type                                                     object
# Completion Status                                                  object
# Project Name                                                       object
# Expenditure Category Group                                         object
# Expenditure Category                                               object
# Project Description                                                object
# Adopted Budget                                                     object
# Total Cumulative Obligations                                       object
# Total Cumulative Expenditures                                      object
# Community benefit agreement? (Infrastructure Only)                 object
# Complying with David Bacon? (Infrastructure Only)                  object
# Project labor agreement? (Infrastructure Only)                     object
# Primary Demographic Served (Select Expenditure Categories Only)    object
# dtype: object

# %%
# clean up values preventing change of data type to int
covid_projects_df[['Adopted Budget','Total Cumulative Obligations',
                   'Total Cumulative Expenditures']] = covid_projects_df[['Adopted Budget',
       'Total Cumulative Obligations', 'Total Cumulative Expenditures']].replace(['-', ' '] ,'', regex=True)


numeric_cols = ['Adopted Budget',
       'Total Cumulative Obligations', 'Total Cumulative Expenditures']


# convert budget columns to int for summarizing in groupby:
covid_projects_df = covid_projects_df.replace(',','', regex=True)
covid_projects_df[numeric_cols] = covid_projects_df[numeric_cols].apply(pd.to_numeric)


print(covid_projects_df['Adopted Budget'].unique())

# print(covid_projects_df.dtypes)

covid_projects_df.head(3)
# Out:
# [       nan 1000000.     28300.   ...  205796.55 1705540.      8265.39]
#    Project ID Recipient-ID                           Recipient Name  \
# 0  TPN-039343   RCP-039196                     Woodbury County Iowa
# 1  TPN-039461   RCP-036070  Lexington-Fayette Urban County Kentucky
# 5  TPN-055785   RCP-035970                           State Of Idaho
#
#   State/Territory StateList  \
# 0            Iowa      Iowa
# 1        Kentucky  Kentucky
# 5           Idaho     Idaho
#
#                                       Reporting Tier    Recipient Type  \
# 0  Tier 2.  Metropolitan cities and counties with...  Local Government
# 1  Tier 1. States U.S. territories metropolitan c...  Local Government
# 5  Tier 1. States U.S. territories metropolitan c...          State/DC
#
#   Completion Status                            Project Name  \
# 0         Cancelled                        LEC Main project
# 1         Cancelled  Housing Stabilization - Salvation Army
# 5         Cancelled              Reserve for Covid 19 costs
#
#   Expenditure Category Group  \
# 0            1-Public Health
# 1      6-Revenue Replacement
# 5            1-Public Health
#
#                                 Expenditure Category  \
# 0  1.4-Prevention in Congregate Settings (Nursing...
# 1               6.1-Provision of Government Services
# 5                  1.14-Other Public Health Services
#
#                                  Project Description  Adopted Budget  \
# 0                             hvac to mitigate covid             NaN
# 1  financial assistance to salvation army to impr...             NaN
# 5       additional unanticipated covid medical costs             NaN
#
#    Total Cumulative Obligations  Total Cumulative Expenditures  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 5                           NaN                            NaN
#
#   Community benefit agreement? (Infrastructure Only)  \
# 0                                                NaN
# 1                                                NaN
# 5                                                NaN
#
#   Complying with David Bacon? (Infrastructure Only)  \
# 0                                               NaN
# 1                                               NaN
# 5                                               NaN
#
#   Project labor agreement? (Infrastructure Only)  \
# 0                                            NaN
# 1                                            NaN
# 5                                            NaN
#
#   Primary Demographic Served (Select Expenditure Categories Only)
# 0                               1 Imp General Public
# 1                                                NaN
# 5                               1 Imp General Public

# %%
# Try to group the filtered dataframe by state, summing applicable $ value columns
    ## if we get errors, then we need to clean columns causing errors. 
    ## eg) 'Adopted Budget' column has values containing "-". This might prevent the .sum() function from working

# example) covid_projects_df.groupby(['State/Territory']).sum(['Adopted Budget', 'Total Cumulative Obligations', 'Total Cumulative Expenditures'])


state_spending_df = covid_projects_df.groupby(['State/Territory'], as_index=False).sum(['Adopted Budget', 'Total Cumulative Obligations', 
                                                                        'Total Cumulative Expenditures'])

print(f'The column headers for the state_spending_df are:\n\n {state_spending_df.columns}')
state_spending_df.head()
# Out:
# The column headers for the state_spending_df are:
#
#  Index(['State/Territory', 'Adopted Budget', 'Total Cumulative Obligations',
#        'Total Cumulative Expenditures'],
#       dtype='object')
#   State/Territory  Adopted Budget  Total Cumulative Obligations  \
# 0         Alabama    3.418569e+08                  2.399945e+08
# 1          Alaska    8.992231e+07                  5.085797e+07
# 2  American Samoa    4.478663e+08                  3.276864e+07
# 3         Arizona    1.530397e+09                  9.914961e+08
# 4        Arkansas    1.611468e+08                  1.597260e+08
#
#    Total Cumulative Expenditures
# 0                   1.922303e+08
# 1                   4.789568e+07
# 2                   3.022634e+07
# 3                   6.932362e+08
# 4                   1.442925e+08

# %%
# Add column of state name abbreviations:
# source: https://gist.github.com/rogerallen/1583593

us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "Virgin Islands": "VI",
}
    
# add abbreviated state name column and reorder so the abbrev is after full state name column:
state_spending_df['Location'] = state_spending_df['State/Territory'].map(us_state_to_abbrev)
state_spending_df = state_spending_df[['State/Territory', 'Location', 'Adopted Budget', 
                                       'Total Cumulative Obligations', 'Total Cumulative Expenditures']]

state_spending_df
# Out:
#              State/Territory Location  Adopted Budget  \
# 0                    Alabama       AL    3.418569e+08
# 1                     Alaska       AK    8.992231e+07
# 2             American Samoa       AS    4.478663e+08
# 3                    Arizona       AZ    1.530397e+09
# 4                   Arkansas       AR    1.611468e+08
# 5                 California       CA    2.224030e+10
# 6                   Colorado       CO    7.885279e+08
# 22                  1.434188e+09                   1.327333e+09
# 23                  1.814665e+09                   1.664885e+09
# 24                  1.169425e+09                   7.576897e+08
# 25                  3.527993e+08                   3.165548e+08
# 26                  6.761716e+07                   6.430986e+07
# 27                  2.351193e+08                   6.681272e+07
# 28                  6.019568e+07                   4.142798e+07
# 29                  1.026929e+08                   9.594920e+07
# 30                  5.186015e+08                   1.433677e+08
# 31                  1.677572e+08                   1.076148e+08
# 32                  1.408578e+09                   1.120432e+09
# 33                  8.702208e+07                   7.250311e+07
# 34                  3.419438e+09                   3.331159e+09
# 35                  1.534649e+09                   1.019276e+09
# 36                  2.936548e+06                   2.381691e+06
# 37                  2.753598e+08                   2.734921e+08
# 38                  2.603933e+08                   2.059655e+08
# 39                  1.429468e+08                   2.580459e+07
# 40                  3.496120e+08                   3.045434e+08
# 41                  3.739155e+08                   2.808885e+08
# 42                  7.726769e+08                   7.270726e+08
# 43                  6.142701e+07                   4.339684e+07
# 44                  1.247084e+08                   9.873393e+07
# 45                  4.266985e+06                   2.118547e+06
# 46                  2.949101e+08                   1.906656e+08
# 47                  3.313769e+09                   2.581972e+09
# 48                  1.256613e+08                   1.186516e+08
# 49                  9.553103e+07                   7.090888e+07
# 50                  3.105238e+07                   2.609072e+07
# 51                  1.537710e+08                   1.299791e+08
# 52                  5.829482e+08                   4.499773e+08
# 53                  1.606806e+07                   1.269122e+07
# 54                  5.282344e+08                   2.449534e+08
# 55                  1.222120e+07                   2.337342e+06

# %%
# "all_us_projects_df" is for (2) from Joanna's slack message request:
all_us_projects_df = all_states_df[['Recipient Name', 'State/Territory', 'Recipient Type', 
                                    'Completion Status', 'Project Name', 'Expenditure Category Group', 'Expenditure Category', 
                                    'Project Description', 'Adopted Budget', 'Total Cumulative Obligations', 
                                    'Total Cumulative Expenditures']].copy()


all_us_projects_df['State/Territory'] = all_us_projects_df['State/Territory'].map(us_state_to_abbrev)
all_us_projects_df.rename(columns = {'State/Territory':'State'}, inplace = True)

all_us_projects_df[['Adopted Budget','Total Cumulative Obligations',
                   'Total Cumulative Expenditures']] = all_us_projects_df[['Adopted Budget',
       'Total Cumulative Obligations', 'Total Cumulative Expenditures']].replace(['-', ' '] ,'', regex=True)


numeric_cols = ['Adopted Budget',
       'Total Cumulative Obligations', 'Total Cumulative Expenditures']


# convert budget columns to int for summarizing in groupby:
all_us_projects_df = all_us_projects_df.replace(',','', regex=True)
all_us_projects_df[numeric_cols] = all_us_projects_df[numeric_cols].apply(pd.to_numeric)

# all_us_projects_df.dtypes
all_us_projects_df.head(3)
# Out:
#                             Recipient Name State    Recipient Type  \
# 0                     Woodbury County Iowa    IA  Local Government
# 1  Lexington-Fayette Urban County Kentucky    KY  Local Government
# 2  Lexington-Fayette Urban County Kentucky    KY  Local Government
#
#   Completion Status                            Project Name  \
# 0         Cancelled                        LEC Main project
# 1         Cancelled  Housing Stabilization - Salvation Army
# 2         Cancelled               Non-Profit Capital Grants
#
#   Expenditure Category Group  \
# 0            1-Public Health
# 1      6-Revenue Replacement
# 2      6-Revenue Replacement
#
#                                 Expenditure Category  \
# 0  1.4-Prevention in Congregate Settings (Nursing...
# 1               6.1-Provision of Government Services
# 2               6.1-Provision of Government Services
#
#                                  Project Description  Adopted Budget  \
# 0                             hvac to mitigate covid             NaN
# 1  financial assistance to salvation army to impr...             NaN
# 2  the nonprofit capital project grants program i...             NaN
#
#    Total Cumulative Obligations  Total Cumulative Expenditures
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN

# %%
# "us_covid_projects_df" is for (3) from Joanna's slack message:
us_covid_projects_df = all_us_projects_df[all_us_projects_df['Project Description'].str.contains('|'.join(search_term_list))]


# print(len(all_states_df['Project Description']))
print(f'The number of rows containing covid/vaccine search criteria terms is {len(us_covid_projects_df["Project Name"])}')
us_covid_projects_df.head()
# Out:
# The number of rows containing covid/vaccine search criteria terms is 8225
#                              Recipient Name State    Recipient Type  \
# 0                      Woodbury County Iowa    IA  Local Government
# 1   Lexington-Fayette Urban County Kentucky    KY  Local Government
# 5                            State Of Idaho    ID          State/DC
# 10                           State Of Idaho    ID          State/DC
# 13                           State Of Idaho    ID          State/DC
#
#    Completion Status                            Project Name  \
# 0          Cancelled                        LEC Main project
# 1          Cancelled  Housing Stabilization - Salvation Army
# 5          Cancelled              Reserve for Covid 19 costs
# 10         Cancelled                       DHW Home visiting
# 13         Cancelled                  EMS Ambulance capacity
#
#      Expenditure Category Group  \
# 0               1-Public Health
# 1         6-Revenue Replacement
# 5               1-Public Health
# 10  2-Negative Economic Impacts
# 13              1-Public Health
#
#                                  Expenditure Category  \
# 0   1.4-Prevention in Congregate Settings (Nursing...
# 1                6.1-Provision of Government Services
# 5                   1.14-Other Public Health Services
# 10  2.12-Healthy Childhood Environments: Home Visi...
# 13           1.10-COVID-19 Aid to Impacted Industries
#
#                                   Project Description  Adopted Budget  \
# 0                              hvac to mitigate covid             NaN
# 1   financial assistance to salvation army to impr...             NaN
# 5        additional unanticipated covid medical costs             NaN
# 10  •\tthe idaho department of health and welfare ...             NaN
# 13  •\tthe idaho legislature appropriated $2500000...             NaN
#
#     Total Cumulative Obligations  Total Cumulative Expenditures
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 5                            NaN                            NaN
# 10                           NaN                            NaN
# 13                           NaN                            NaN

# %%
#TODO: Collect and clean data for (1) from Joanna's slack message request

# %% [markdown]
# ## Aaliyah Work Area

# %%
# import and read the state_summary.csv
# Load csv file(s)
state_summary_sheet = Path("Resources/state_summary.csv")


# Read csv file(s) as a DataFrame
state_summary_df = pd.read_csv(state_summary_sheet, skipinitialspace= True)


state_summary_df.head()
# Out:
#         State Total state allocation (from the fed)  \
# 0     Alabama                        $2,120,279,417
# 1      Alaska                        $1,011,788,220
# 2     Arizona                        $4,182,827,492
# 3    Arkansas                        $1,573,121,581
# 4  California                       $27,017,016,860
#
#   total state plus total local federal grant Total state spending  \
# 0                             $3,287,582,722        $348,913,764
# 1                             $1,166,360,017        $865,562,003
# 2                             $6,621,288,758      $2,120,555,074
# 3                             $2,112,900,112        $616,773,435
# 4                            $41,419,307,889     $20,188,839,813
#
#   Spent as of Sept 30, 2022 Total state obligated Total state budgeted  \
# 0             $340,112,472          $350,199,320       $1,060,139,709
# 1             $805,280,930          $884,653,257       $1,001,201,989
# 2           $1,923,020,697        $2,496,788,343       $2,792,726,506
# 3             $546,907,964          $660,527,986         $767,344,936
# 4          $19,629,506,051       $24,826,648,677      $26,933,816,205
#
#   Share of state allocation spent Share of state allocation obligated  \
# 0                           16.5%                               16.5%
# 1                           85.5%                               87.4%
# 2                           50.7%                               59.7%
# 3                           39.2%                               42.0%
# 4                           74.7%                               91.9%
#
#   Share of state allocation budgeted  ... Share of local spent  \
# 0                              50.0%  ...                20.5%
# 1                              99.0%  ...                62.5%
# 2                              66.8%  ...                30.6%
# 3                              48.8%  ...                32.4%
# 4                              99.7%  ...                37.1%
#
#   Share of local obligated Share of local budgeted  \
# 0                    35.0%                   23.6%
# 1                    70.4%                   78.0%
# 2                    43.3%                   76.1%
# 3                    49.3%                   30.9%
# 4                    46.4%                   67.2%
#
#   Share of state + local spent  \
# 0                          18%
# 1                          82%
# 2                          43%
# 3                          37%
# 4                          62%
#
#   Change in state spending since Sept (as share of total allocation)  \
# 0                                              0.42%
# 1                                              5.96%
# 2                                              4.72%
# 3                                              4.44%
# 4                                              2.07%
#
#   Change in local spending since Sept  \
# 0                                4.1%
# 1                               31.2%
# 2                                3.3%
# 3                                8.1%
# 4                                4.3%
#
#   Change in local government employment (inclusing public education) from Feb 2020 to Jan 2023  \
# 0                                                0.4
# 1                                               -1.7
# 2                                              -12.0
# 3                                               -2.9
# 4                                              -60.2
#
#   Percentage change in local government employment, February 2020-Jan 2023  \
# 0                                              0.18%
# 1                                             -4.10%
# 2                                             -4.34%
# 3                                             -2.53%
# 4                                             -3.29%
#
#   Change in state government jobs, Feb 2020 to Jan 2023 (thousands  \
# 0                                                0.3
# 1                                               -0.5
# 2                                                0.0
# 3                                               -2.1
# 4                                                7.4
#
#   Percentage change in state government jobs, Feb 2020 to Jan 2023
# 0                                              0.25%
# 1                                             -2.20%
# 2                                              0.00%
# 3                                             -2.68%
# 4                                              1.37%
#
# [5 rows x 25 columns]

# %%
# create a reduced dataframe from the state_summary_df columns: 
    #'State', 'Total state allocation (from the fed)', 'total state plus total local federal grant', 
    #'Share of state allocation spent', 'Share of state allocation obligated', 'Share of state allocation budgeted', 
    #'Total local allocation (from the fed)', 'Share of local spent', 'Share of local obligated', 'Share of local budgeted', 
    #'Share of state + local spent'

import pandas as pd
from pathlib import Path
# Load csv file(s)
state_summary_sheet = Path("Resources/state_summary.csv")

# Read csv file(s) as a DataFrame
state_summary_df = pd.read_csv(state_summary_sheet, skipinitialspace=True)

# Selecting the desired columns
reduced_df = state_summary_df[['State', 'Total state allocation (from the fed)',
                               'total state plus total local federal grant',
                               'Share of state allocation spent', 'Share of state allocation obligated',
                               'Share of state allocation budgeted', 'Total local allocation (from the fed)',
                               'Share of local spent', 'Share of local obligated', 'Share of local budgeted',
                               'Share of state + local spent']]



reduced_df['State'] = reduced_df['State'].replace('_',' ', regex=True)

# add abbreviated state name column and reorder so the abbrev is after full state name column:
reduced_df['Location'] = reduced_df['State'].map(us_state_to_abbrev)


reduced_df.rename(columns = {'State':'State/Territory'}, inplace = True)

# Printing the reduced dataframe
# print(reduced_df.columns)
# print(reduced_df.dtypes)

reduced_df
# Out:
#          State/Territory Total state allocation (from the fed)  \
# 0                Alabama                        $2,120,279,417
# 1                 Alaska                        $1,011,788,220
# 2                Arizona                        $4,182,827,492
# 3               Arkansas                        $1,573,121,581
# 4             California                       $27,017,016,860
# 5               Colorado                        $3,828,761,790
# 6            Connecticut                        $2,812,288,082
# 7               Delaware                          $924,597,608
# 8   District of Columbia                        $2,312,383,930
# 9                Florida                        $8,816,581,839
# 10               Georgia                        $4,853,535,460
# 11                Hawaii                        $1,641,602,610
# 12                 Idaho                        $1,094,018,353
# 13              Illinois                        $8,127,679,949
# 14               Indiana                        $3,071,830,673
# 15                  Iowa                        $1,480,862,558
# 16                Kansas                        $1,583,680,553
# 17              Kentucky                        $2,183,237,291
# 18             Louisiana                        $3,011,136,887
# 19                 Maine                          $997,495,130
# 20              Maryland                        $3,717,212,336
# 21         Massachusetts                        $5,286,067,526
# 22              Michigan                        $6,540,417,627
# 23             Minnesota                        $2,833,294,345
# 24           Mississippi                        $1,806,373,346
# 25              Missouri                        $2,685,296,131
# 26               Montana                          $906,418,527
# 27              Nebraska                        $1,040,157,440
# 28                Nevada                        $2,738,837,229
# 29         New Hampshire                          $994,555,878
# 30            New Jersey                        $6,244,537,956
# 31            New Mexico                        $1,751,542,835
# 32              New York                       $12,744,981,589
# 33        North Carolina                        $5,439,309,692
# 34          North Dakota                        $1,007,502,515
# 35                  Ohio                        $5,368,386,901
# 36              Oklahoma                        $1,870,417,576
# 37                Oregon                        $2,648,024,988
# 38          Pennsylvania                        $7,291,328,098
# 39          Rhode Island                        $1,131,061,057
# 40        South Carolina                        $2,499,067,329
# 41          South Dakota                          $974,478,793
# 42             Tennessee                        $3,725,832,113
# 43                 Texas                       $15,814,388,615
# 44                  Utah                        $1,377,866,888
# 45               Vermont                        $1,049,287,303
# 46              Virginia                        $4,293,727,162
# 47            Washington                        $4,427,709,356
# 48         West Virginia                        $1,355,489,988
# 49             Wisconsin                        $2,533,160,627
# 50               Wyoming                        $1,068,484,768
# 51                   NaN                                   NaN
# 52                   NaN                                   NaN
#
#    total state plus total local federal grant Share of state allocation spent  \
# 0                              $3,287,582,722                           16.5%
# 1                              $1,166,360,017                           85.5%
# 2                              $6,621,288,758                           50.7%
# 3                              $2,112,900,112                           39.2%
# 4                             $41,419,307,889                           74.7%
# 5                              $5,349,707,710                           24.2%
# 6                              $3,783,573,670                           22.8%
# 7                              $1,199,543,057                           19.9%
# 8                              $2,312,383,930                           28.8%
# 9                             $14,944,690,568                           10.8%
# 10                             $7,124,198,618                           28.2%
# 11                             $2,159,739,321                           68.9%
# 12                             $1,422,463,005                           18.3%
# 13                            $12,902,558,821                           64.8%
# 14                             $4,867,234,699                           31.1%
# 15                             $2,121,323,826                           22.6%
# 16                             $2,196,073,473                           34.2%
# 17                             $3,046,206,294                           54.0%
# 18                             $4,298,498,785                           43.1%
# 19                             $1,295,739,500                           24.1%
# 20                             $5,632,845,765                           73.1%
# 21                             $7,872,008,770                           40.1%
# 22                             $9,928,485,178                           25.8%
# 23                             $4,237,448,012                           93.9%
# 24                             $2,185,259,621                            3.8%
# 25                             $4,528,949,649                            2.1%
# 26                             $1,110,761,810                           11.2%
# 27                             $1,419,928,762                           11.8%
# 28                             $3,713,687,939                           17.2%
# 29                             $1,306,953,168                           11.5%
# 30                             $8,994,687,877                           14.6%
# 31                             $2,245,395,555                           40.2%
# 32                            $22,615,632,359                           35.3%
# 33                             $7,904,442,177                           30.7%
# 34                             $1,119,686,000                           30.7%
# 35                             $9,497,111,747                           29.2%
# 36                             $2,671,987,724                            0.4%
# 37                             $3,795,127,019                           50.3%
# 38                            $12,192,782,903                           73.7%
# 39                             $1,522,791,652                           28.0%
# 40                             $3,655,795,231                            0.3%
# 41                             $1,084,405,730                            3.5%
# 42                             $5,257,131,967                            3.0%
# 43                            $24,294,850,984                           57.6%
# 44                             $2,172,084,027                           41.9%
# 45                             $1,076,463,447                           15.4%
# 46                             $6,448,637,212                           42.7%
# 47                             $6,554,589,438                           32.5%
# 48                             $1,688,264,166                           24.8%
# 49                             $4,173,956,565                           39.2%
# 50                             $1,100,003,290                           29.6%
# 51                                        NaN                             NaN
# 52                                        NaN                             NaN
#
#    Share of state allocation obligated Share of state allocation budgeted  \
# 0                                16.5%                              50.0%
# 1                                87.4%                              99.0%
# 2                                59.7%                              66.8%
# 3                                42.0%                              48.8%
# 4                                91.9%                              99.7%
# 5                                36.5%                              82.1%
# 6                                27.5%                              60.7%
# 7                                43.5%                              83.3%
# 8                                48.8%                             100.0%
# 9                                44.9%                              89.6%
# 10                               75.1%                              86.2%
# 11                               76.3%                              98.1%
# 12                               18.3%                              95.0%
# 13                               71.6%                              80.3%
# 14                               63.2%                             100.0%
# 15                               59.6%                              77.0%
# 16                               47.4%                              52.4%
# 17                               54.0%                              60.7%
# 18                               52.3%                             100.0%
# 19                               62.4%                              98.0%
# 20                               82.7%                              99.8%
# 21                               42.9%                              52.4%
# 22                               29.9%                              72.2%
# 23                               97.8%                             100.0%
# 24                                5.0%                              65.0%
# 25                               10.2%                              24.1%
# 26                               32.9%                              37.5%
# 27                               23.6%                              60.9%
# 28                               33.1%                              44.8%
# 29                               31.1%                              90.8%
# 30                               20.0%                              34.3%
# 31                               45.8%                              80.4%
# 32                               35.3%                              35.3%
# 33                               70.5%                             100.0%
# 34                               93.8%                              93.8%
# 35                               37.1%                              41.0%
# 36                               14.0%                              55.6%
# 37                               60.3%                              79.7%
# 38                               75.5%                              83.9%
# 39                               53.3%                              63.0%
# 40                               14.7%                              14.9%
# 41                               60.4%                              73.9%
# 42                                7.1%                              68.5%
# 43                               64.8%                              67.0%
# 44                               42.0%                              88.0%
# 45                               39.0%                              81.6%
# 46                               58.1%                              95.5%
# 47                               50.0%                              87.6%
# 48                               28.0%                              32.1%
# 49                               80.9%                             100.0%
# 50                               62.9%                              65.9%
# 51                                 NaN                                NaN
# 52                                 NaN                                NaN
#
#    Total local allocation (from the fed) Share of local spent  \
# 0                         $1,167,303,305                20.5%
# 1                           $154,571,797                62.5%
# 2                         $2,438,461,266                30.6%
# 3                           $539,778,531                32.4%
# 4                        $14,402,291,029                37.1%
# 5                         $1,520,945,920                32.8%
# 6                           $971,285,588                24.0%
# 7                           $274,945,449                21.6%
# 8                                    NaN                  NaN
# 9                         $6,128,108,729                36.3%
# 10                        $2,270,663,158                31.2%
# 11                          $518,136,711                17.4%
# 12                          $328,444,652                10.5%
# 13                        $4,774,878,872                38.1%
# 14                        $1,795,404,026                23.6%
# 15                          $640,461,268                26.4%
# 16                          $612,392,920                31.6%
# 17                          $862,969,003                28.2%
# 18                        $1,287,361,898                25.3%
# 19                          $298,244,370                11.0%
# 20                        $1,915,633,429                29.2%
# 21                        $2,585,941,244                23.5%
# 22                        $3,388,067,551                13.8%
# 23                        $1,404,153,667                33.1%
# 24                          $378,886,275                16.2%
# 25                        $1,843,653,518                23.2%
# 26                          $204,343,283                15.9%
# 27                          $379,771,322                46.7%
# 28                          $974,850,710                52.7%
# 29                          $312,397,290                27.2%
# 30                        $2,750,149,921                41.2%
# 31                          $493,852,720                31.7%
# 32                        $9,870,650,770                49.0%
# 33                        $2,465,132,485                27.8%
# 34                          $112,183,485                21.4%
# 35                        $4,128,724,846                35.0%
# 36                          $801,570,148                15.6%
# 37                        $1,147,102,031                35.8%
# 38                        $4,901,454,805                28.2%
# 39                          $391,730,595                21.0%
# 40                        $1,156,727,902                30.2%
# 41                          $109,926,937                32.5%
# 42                        $1,531,299,854                32.3%
# 43                        $8,480,462,369                23.6%
# 44                          $794,217,139                27.7%
# 45                           $27,176,144                50.5%
# 46                        $2,154,910,050                30.5%
# 47                        $2,126,880,082                32.7%
# 48                          $332,774,178                34.2%
# 49                        $1,640,795,938                19.6%
# 50                           $31,518,522                31.1%
# 51                                   NaN                  NaN
# 52                                   NaN                  NaN
#
#    Share of local obligated Share of local budgeted  \
# 0                     35.0%                   23.6%
# 1                     70.4%                   78.0%
# 2                     43.3%                   76.1%
# 3                     49.3%                   30.9%
# 4                     46.4%                   67.2%
# 5                     44.0%                   69.0%
# 6                     43.6%                   50.8%
# 7                     31.2%                   19.0%
# 8                       NaN                     NaN
# 9                     52.2%                   67.9%
# 10                    46.9%                   49.9%
# 11                    25.2%                   31.2%
# 12                    23.7%                   40.2%
# 13                    49.0%                   71.2%
# 14                    44.5%                   40.9%
# 15                    45.7%                   39.4%
# 16                    45.8%                   54.1%
# 17                    47.2%                   67.6%
# 18                    37.8%                   46.7%
# 19                    30.0%                   30.6%
# 20                    44.1%                   55.6%
# 21                    39.1%                   40.5%
# 22                    28.7%                   39.1%
# 23                    42.2%                   71.0%
# 24                    26.4%                   25.6%
# 25                    37.2%                   59.2%
# 26                    40.0%                   29.3%
# 27                    61.8%                   60.3%
# 28                    63.5%                   71.2%
# 29                    41.7%                   24.3%
# 30                    51.5%                   55.4%
# 31                    57.4%                   75.6%
# 32                    54.5%                   79.2%
# 33                    40.7%                   50.7%
# 34                    37.2%                   38.1%
# 35                    49.0%                   48.7%
# 36                    39.8%                   44.9%
# 37                    47.7%                   55.3%
# 38                    35.3%                   46.1%
# 39                    29.1%                   31.8%
# 40                    48.8%                   43.8%
# 41                    37.5%                   26.2%
# 42                    64.8%                   64.4%
# 43                    39.3%                   59.4%
# 44                    36.4%                   49.6%
# 45                    50.5%                    0.0%
# 46                    47.2%                   51.2%
# 47                    48.3%                   62.2%
# 48                    48.0%                   25.6%
# 49                    37.5%                   44.5%
# 50                    92.5%                   43.4%
# 51                      NaN                     NaN
# 52                      NaN                     NaN
#
#    Share of state + local spent Location
# 0                           18%       AL
# 1                           82%       AK
# 2                           43%       AZ
# 3                           37%       AR
# 4                           62%       CA
# 5                           27%       CO
# 6                           23%       CT
# 7                           20%       DE
# 8                           29%       DC
# 9                           21%       FL
# 10                          29%       GA
# 11                          57%       HI
# 12                          16%       ID
# 13                          55%       IL
# 14                          28%       IN
# 15                          24%       IA
# 16                          33%       KS
# 17                          47%       KY
# 18                          38%       LA
# 19                          21%       ME
# 20                          58%       MD
# 21                          35%       MA
# 22                          22%       MI
# 23                          74%       MN
# 24                           6%       MS
# 25                          11%       MO
# 26                          12%       MT
# 27                          21%       NE
# 28                          27%       NV
# 29                          15%       NH
# 30                          23%       NJ
# 31                          38%       NM
# 32                          41%       NY
# 33                          30%       NC
# 34                          30%       ND
# 35                          32%       OH
# 36                           5%       OK
# 37                          46%       OR
# 38                          55%       PA
# 39                          26%       RI
# 40                          10%       SC
# 41                           6%       SD
# 42                          12%       TN
# 43                          46%       TX
# 44                          37%       UT
# 45                          16%       VT
# 46                          39%       VA
# 47                          33%       WA
# 48                          27%       WV
# 49                          31%       WI
# 50                          30%       WY
# 51                          NaN      NaN
# 52                          NaN      NaN

# %%
# convert all budget columns to numeric values
# drop non-number values first:

reduced_df[['Total state allocation (from the fed)', 
            'total state plus total local federal grant',
            'Total local allocation (from the fed)']] = reduced_df[['Total state allocation (from the fed)', 
            'total state plus total local federal grant',
            'Total local allocation (from the fed)']].replace(['\$', '-', ' '] ,'', regex=True)


numeric_cols = ['Total state allocation (from the fed)', 
            'total state plus total local federal grant',
            'Total local allocation (from the fed)']


# convert budget columns to int for summarizing in groupby:
reduced_df = reduced_df.replace(',','', regex=True)
reduced_df[numeric_cols] = reduced_df[numeric_cols].apply(pd.to_numeric)

# reduced_df.dtypes
print(reduced_df.dtypes)
reduced_df.head()
# Out:
# State/Territory                                object
# Total state allocation (from the fed)         float64
# total state plus total local federal grant    float64
# Share of state allocation spent                object
# Share of state allocation obligated            object
# Share of state allocation budgeted             object
# Total local allocation (from the fed)         float64
# Share of local spent                           object
# Share of local obligated                       object
# Share of local budgeted                        object
# Share of state + local spent                   object
# Location                                       object
# dtype: object
#   State/Territory  Total state allocation (from the fed)  \
# 0         Alabama                           2.120279e+09
# 1          Alaska                           1.011788e+09
# 2         Arizona                           4.182827e+09
# 3        Arkansas                           1.573122e+09
# 4      California                           2.701702e+10
#
#    total state plus total local federal grant Share of state allocation spent  \
# 0                                3.287583e+09                           16.5%
# 1                                1.166360e+09                           85.5%
# 2                                6.621289e+09                           50.7%
# 3                                2.112900e+09                           39.2%
# 4                                4.141931e+10                           74.7%
#
#   Share of state allocation obligated Share of state allocation budgeted  \
# 0                               16.5%                              50.0%
# 1                               87.4%                              99.0%
# 2                               59.7%                              66.8%
# 3                               42.0%                              48.8%
# 4                               91.9%                              99.7%
#
#    Total local allocation (from the fed) Share of local spent  \
# 0                           1.167303e+09                20.5%
# 1                           1.545718e+08                62.5%
# 2                           2.438461e+09                30.6%
# 3                           5.397785e+08                32.4%
# 4                           1.440229e+10                37.1%
#
#   Share of local obligated Share of local budgeted  \
# 0                    35.0%                   23.6%
# 1                    70.4%                   78.0%
# 2                    43.3%                   76.1%
# 3                    49.3%                   30.9%
# 4                    46.4%                   67.2%
#
#   Share of state + local spent Location
# 0                          18%       AL
# 1                          82%       AK
# 2                          43%       AZ
# 3                          37%       AR
# 4                          62%       CA

# %%
# Now replace percentage string values with a decimal float value dtype:

# reduced_df[['Share of state allocation spent', 'Share of state allocation obligated', 'Share of state allocation budgeted']] = reduced_df[['Share of state allocation spent', 'Share of state allocation obligated', 'Share of state allocation budgeted']].str.rstrip('%').astype('float') / 100.0

convert_cols = ['Share of state allocation spent', 'Share of state allocation obligated', 'Share of state allocation budgeted', 'Share of local spent', 'Share of local obligated', 'Share of local budgeted', 'Share of state + local spent']

reduced_df = reduced_df.replace('%','', regex=True)

reduced_df[convert_cols] = reduced_df[convert_cols].astype(float)/100


print(reduced_df.dtypes)
reduced_df.head()
# Out:
# State/Territory                                object
# Total state allocation (from the fed)         float64
# total state plus total local federal grant    float64
# Share of state allocation spent               float64
# Share of state allocation obligated           float64
# Share of state allocation budgeted            float64
# Total local allocation (from the fed)         float64
# Share of local spent                          float64
# Share of local obligated                      float64
# Share of local budgeted                       float64
# Share of state + local spent                  float64
# Location                                       object
# dtype: object
#   State/Territory  Total state allocation (from the fed)  \
# 0         Alabama                           2.120279e+09
# 1          Alaska                           1.011788e+09
# 2         Arizona                           4.182827e+09
# 3        Arkansas                           1.573122e+09
# 4      California                           2.701702e+10
#
#    total state plus total local federal grant  \
# 0                                3.287583e+09
# 1                                1.166360e+09
# 2                                6.621289e+09
# 3                                2.112900e+09
# 4                                4.141931e+10
#
#    Share of state allocation spent  Share of state allocation obligated  \
# 0                            0.165                                0.165
# 1                            0.855                                0.874
# 2                            0.507                                0.597
# 3                            0.392                                0.420
# 4                            0.747                                0.919
#
#    Share of state allocation budgeted  Total local allocation (from the fed)  \
# 0                               0.500                           1.167303e+09
# 1                               0.990                           1.545718e+08
# 2                               0.668                           2.438461e+09
# 3                               0.488                           5.397785e+08
# 4                               0.997                           1.440229e+10
#
#    Share of local spent  Share of local obligated  Share of local budgeted  \
# 0                 0.205                     0.350                    0.236
# 1                 0.625                     0.704                    0.780
# 2                 0.306                     0.433                    0.761
# 3                 0.324                     0.493                    0.309
# 4                 0.371                     0.464                    0.672
#
#    Share of state + local spent Location
# 0                          0.18       AL
# 1                          0.82       AK
# 2                          0.43       AZ
# 3                          0.37       AR
# 4                          0.62       CA

# %%
# merge this data frame with Evan's "state_spending_df". Merge on the state columns.
    # https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html
    # https://www.geeksforgeeks.org/how-to-join-pandas-dataframes-using-merge/#

EARN_states = pd.merge(state_spending_df, reduced_df, how ='inner', on =(['State/Territory', 'Location']))

EARN_states.head(3)
# Out:
#   State/Territory Location  Adopted Budget  Total Cumulative Obligations  \
# 0         Alabama       AL    3.418569e+08                  2.399945e+08
# 1          Alaska       AK    8.992231e+07                  5.085797e+07
# 2         Arizona       AZ    1.530397e+09                  9.914961e+08
#
#    Total Cumulative Expenditures  Total state allocation (from the fed)  \
# 0                   1.922303e+08                           2.120279e+09
# 1                   4.789568e+07                           1.011788e+09
# 2                   6.932362e+08                           4.182827e+09
#
#    total state plus total local federal grant  \
# 0                                3.287583e+09
# 1                                1.166360e+09
# 2                                6.621289e+09
#
#    Share of state allocation spent  Share of state allocation obligated  \
# 0                            0.165                                0.165
# 1                            0.855                                0.874
# 2                            0.507                                0.597
#
#    Share of state allocation budgeted  Total local allocation (from the fed)  \
# 0                               0.500                           1.167303e+09
# 1                               0.990                           1.545718e+08
# 2                               0.668                           2.438461e+09
#
#    Share of local spent  Share of local obligated  Share of local budgeted  \
# 0                 0.205                     0.350                    0.236
# 1                 0.625                     0.704                    0.780
# 2                 0.306                     0.433                    0.761
#
#    Share of state + local spent
# 0                          0.18
# 1                          0.82
# 2                          0.43

# %%
# Add column to shows [Total Cumulative Expenditures]/[total state plus total local federal grant]
# sortby this new percent column.

EARN_states['Percent Spent'] = EARN_states['Total Cumulative Expenditures']/EARN_states['total state plus total local federal grant']

EARN_states.sort_values(by=['Percent Spent'], ascending=False, inplace= True)

EARN_states
# Out:
#          State/Territory Location  Adopted Budget  \
# 4             California       CA    2.224030e+10
# 20              Maryland       MD    1.801403e+09
# 16                Kansas       KS    5.841607e+08
# 21         Massachusetts       MA    2.081072e+09
# 17              Kentucky       KY    6.601113e+08
# 13              Illinois       IL    3.404191e+09
# 32              New York       NY    4.826532e+09
# 33        North Carolina       NC    1.553857e+09
# 30            New Jersey       NJ    1.938698e+09
# 19                 Maine       ME    3.963270e+08
# 43                 Texas       TX    4.331832e+09
# 2                Arizona       AZ    1.530397e+09
# 29         New Hampshire       NH    3.797825e+08
# 37                Oregon       OR    4.757801e+08
# 22              Michigan       MI    2.185694e+09
# 7               Delaware       DE    1.468774e+08
# 23             Minnesota       MN    3.967240e+08
# 47            Washington       WA    7.541905e+08
# 3               Arkansas       AR    1.611468e+08
# 27              Nebraska       NE    1.576127e+08
# 45               Vermont       VT    1.848229e+08
# 8   District of Columbia       DC    1.779510e+08
# 9                Florida       FL    2.310322e+09
# 5               Colorado       CO    7.885279e+08
# 49             Wisconsin       WI    6.781258e+08
# 0                Alabama       AL    3.418569e+08
# 44                  Utah       UT    3.165399e+08
# 10               Georgia       GA    1.282150e+09
# 6            Connecticut       CT    5.419699e+08
# 1                 Alaska       AK    8.992231e+07
# 28                Nevada       NV    5.690831e+08
# 26               Montana       MT    4.699826e+07
# 11                Hawaii       HI    2.080165e+08
# 42             Tennessee       TN    5.562359e+08
# 31            New Mexico       NM    9.325325e+07
# 24           Mississippi       MS    3.225288e+08
# 39          Rhode Island       RI    1.027943e+08
# 18             Louisiana       LA    1.884563e+08
# 40        South Carolina       SC    1.037992e+08
# 43                 0.236                     0.393                    0.594
# 2                  0.306                     0.433                    0.761
# 29                 0.272                     0.417                    0.243
# 37                 0.358                     0.477                    0.553
# 22                 0.138                     0.287                    0.391
# 7                  0.216                     0.312                    0.190
# 23                 0.331                     0.422                    0.710
# 47                 0.327                     0.483                    0.622
# 3                  0.324                     0.493                    0.309
# 27                 0.467                     0.618                    0.603
# 45                 0.505                     0.505                    0.000
# 8                    NaN                       NaN                      NaN
# 9                  0.363                     0.522                    0.679
# 5                  0.328                     0.440                    0.690
# 49                 0.196                     0.375                    0.445
# 0                  0.205                     0.350                    0.236
# 44                 0.277                     0.364                    0.496
# 10                 0.312                     0.469                    0.499
# 6                  0.240                     0.436                    0.508
# 1                  0.625                     0.704                    0.780
# 28                 0.527                     0.635                    0.712
# 26                 0.159                     0.400                    0.293
# 11                 0.174                     0.252                    0.312
# 42                 0.323                     0.648                    0.644
# 31                 0.317                     0.574                    0.756
# 24                 0.162                     0.264                    0.256
# 39                 0.210                     0.291                    0.318
# 18                 0.253                     0.378                    0.467
# 40                 0.302                     0.488                    0.438
# 12                 0.105                     0.237                    0.402
# 38                 0.282                     0.353                    0.461
# 35                 0.350                     0.490                    0.487
# 46                 0.305                     0.472                    0.512
# 25                 0.232                     0.372                    0.592
# 14                 0.236                     0.445                    0.409
# 15                 0.264                     0.457                    0.394
# 36                 0.156                     0.398                    0.449
# 48                 0.342                     0.480                    0.256
# 34                 0.214                     0.372                    0.381
# 50                 0.311                     0.925                    0.434
# 41                 0.325                     0.375                    0.262
#
#     Share of state + local spent  Percent Spent
# 4                           0.62       0.483136
# 20                          0.58       0.235642
# 16                          0.33       0.227969
# 21                          0.35       0.211494
# 17                          0.47       0.204117
# 13                          0.55       0.198283
# 32                          0.41       0.147295
# 33                          0.30       0.128950
# 30                          0.23       0.124566
# 19                          0.21       0.123218
# 43                          0.46       0.106277
# 2                           0.43       0.104698
# 29                          0.15       0.082340
# 37                          0.46       0.080246
# 22                          0.22       0.076315
# 7                           0.20       0.074810
# 23                          0.74       0.074704
# 47                          0.33       0.068651
# 3                           0.37       0.068291
# 27                          0.21       0.067573
# 45                          0.16       0.065872
# 8                           0.29       0.063367
# 9                           0.21       0.062294
# 5                           0.27       0.061233
# 49                          0.31       0.058686
# 0                           0.18       0.058472
# 44                          0.37       0.054626
# 10                          0.29       0.050794
# 6                           0.23       0.048485
# 1                           0.82       0.041064
# 28                          0.27       0.038605
# 26                          0.12       0.037297
# 11                          0.57       0.037149
# 42                          0.12       0.036268
# 31                          0.38       0.032290
# 24                          0.06       0.029429
# 39                          0.26       0.028498
# 18                          0.38       0.027373
# 40                          0.10       0.027008
# 12                          0.16       0.026548
# 38                          0.55       0.023037
# 35                          0.32       0.021687
# 46                          0.39       0.020156
# 25                          0.11       0.014752
# 14                          0.28       0.014067
# 15                          0.24       0.010666
# 36                          0.05       0.009657
# 48                          0.27       0.007517
# 34                          0.30       0.002127
# 50                          0.30       0.002125
# 41                          0.06       0.001954

# %%
# Now do combined bar and line chart. Line shows [total state plus total local federal grant]
# bar shows Percent Spent
# x-axis is state name
